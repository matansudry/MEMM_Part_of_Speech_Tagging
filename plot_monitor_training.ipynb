# %%
import time
from IPython.display import clear_output
from utils import classifier

# %%
while True:
    model = classifier.load_model(version=11, models_path='models', epoch=-1, prints=False)
    clear_output(wait=True)
    display(model.log.tail(10).iloc[::-1])
#     model.plot(['val_loss', 'train_loss'], 'loss', 'loss', scale='linear', basey=10)
    time.sleep(2)
# Out:
#     train_time            timestamp  train_loss  val_loss  train_score  \
# 67  493.289164  13:23:22 20-04-2020    2.804043  3.659252          0.0
# 66  479.965828  13:10:00 20-04-2020    2.833518  3.688413          0.0
# 65  466.708728  12:56:42 20-04-2020    2.873311  3.729849          0.0
# 64  453.447536  12:43:24 20-04-2020    2.932439  3.781594          0.0
# 63  440.081736  12:30:00 20-04-2020    2.984793  3.816226          0.0
# 62  426.724069  12:16:36 20-04-2020    3.066681  3.861171          0.0
# 61  413.300527  12:03:09 20-04-2020    3.176438  3.937235          0.0
# 60  399.977267  11:49:47 20-04-2020    3.309245  4.052838          0.0
# 59  386.682671  11:36:27 20-04-2020    3.533236  4.285321          0.0
# 58  373.171724  11:22:54 20-04-2020    3.756187  4.492947          0.0
#
#     val_score batch_size  best  weight_decay train_aprox val_aprox beam
# 67        0.0       5000  True           0.0           0         0    1
# 66        0.0       5000  True           0.0           0         0    1
# 65        0.0       5000  True           0.0           0         0    1
# 64        0.0       5000  True           0.0           0         0    1
# 63        0.0       5000  True           0.0           0         0    1
# 62        0.0       5000  True           0.0           0         0    1
# 61        0.0       5000  True           0.0           0         0    1
# 60        0.0       5000  True           0.0           0         0    1
# 59        0.0       5000  True           0.0           0         0    1
# 58        0.0       5000  True           0.0           0         0    1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-60f67b4a7a9f> in <module>
#       4     display(model.log.tail(10).iloc[::-1])
#       5 #     model.plot(['val_loss', 'train_loss'], 'loss', 'loss', scale='linear', basey=10)
# ----> 6     time.sleep(2)
#
# KeyboardInterrupt:
